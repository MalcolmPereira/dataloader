# %%
import matplotlib.pyplot as plt

#Elapsed Time

implementation = [
 'Sequential [Batch-250]', 
 'Sequential [Batch-150]', 
 'Parallel [Batch-250][ThreadPool-24]', 
 'Parallel [Batch-250][ThreadPool-4]', 
 'Parallel [Batch-150][ThreadPool-24]',
 'Parallel [Batch-150][ThreadPool-4]',
 'Sequential-Cache [Batch-250]', 
 'Sequential-Cache (Re-Post) [Batch-250]', 
 'Parallel-Cache [Batch-250]', 
 'Parallel-Cache (Re-Post) [Batch-250]',
 'Spring Batch [Batch Size 250]', 
 'Spring Batch [Batch Size 150]' 
]

elapsed_time = [
    18.25, 
    20.55,
    22.39, 
    36.16,
    34.41,
    20.78,
    18.78,
    2.57,
    25.12,
    2.45,
    19,
    21.43
]

plt.figure(figsize=(12, 8))
plt.bar(implementation, elapsed_time, color='blue')
plt.xlabel('Implementation')
plt.ylabel('Elapsed Time')
plt.title('Elapsed Time vs Implementation')

for i in range(len(implementation)):
    plt.text(i, elapsed_time[i], str(elapsed_time[i]), ha='center', va='bottom')

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#JVM Metrics

implementation = [
 'Sequential [Batch-250]', 
 'Sequential [Batch-150]', 
 'Parallel [Batch-250][ThreadPool-24]', 
 'Parallel [Batch-250][ThreadPool-4]', 
 'Parallel [Batch-150][ThreadPool-24]',
 'Parallel [Batch-150][ThreadPool-4]',
 'Sequential-Cache [Batch-250]', 
 'Sequential-Cache (Re-Post) [Batch-250]', 
 'Parallel-Cache [Batch-250]', 
 'Parallel-Cache (Re-Post) [Batch-250]',
 'Spring Batch [Batch Size 250]', 
 'Spring Batch [Batch Size 150]' 
]


jvm_memory = [
    106, 
    105,
    406, 
    342,
    500,
    235,
    109,
    150,
    702,
    211,
    102,
    95.9
]  # Sample JVM Memory values

jvm_cpu = [
    32.1,
    27.3,
    61,
    45.7,
    70.8,
    46.3,
    29.5,
    25.7,
    44.6,
    36.3,
    33.1,
    27.4
]


# Set width of bars
bar_width = 0.35

# Set position of bar on X axis
r1 = np.arange(len(implementation))
r2 = [x + bar_width for x in r1]

# Plotting
#plt.figure(figsize=(10, 6))
plt.figure(figsize=(12, 8))  # Larger figure size

# Plotting JVM Memory
plt.bar(r1, jvm_memory, color='b', width=bar_width, edgecolor='grey', label='JVM Memory -MB')

# Plotting JVM CPU
plt.bar(r2, jvm_cpu, color='r', width=bar_width, edgecolor='grey', label='JVM CPU %')

# Adding values on top of bars
for i in range(len(implementation)):
    plt.text(r1[i] - 0.05, jvm_memory[i] + 5, str(jvm_memory[i]), color='black', fontweight='bold')
    plt.text(r2[i] - 0.05, jvm_cpu[i] + 5, str(jvm_cpu[i]), color='black', fontweight='bold')

# Adding labels and title
plt.xlabel('Implementation', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('JVM Memory and CPU Usage by Implementation')
plt.xticks([r + bar_width / 2 for r in range(len(implementation))], implementation)
plt.legend()

# Displaying plot
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# SQL Server Metrics
implementation = [
 'Sequential [Batch-250]', 
 'Sequential [Batch-150]', 
 'Parallel [Batch-250][ThreadPool-24]', 
 'Parallel [Batch-250][ThreadPool-4]', 
 'Parallel [Batch-150][ThreadPool-24]',
 'Parallel [Batch-150][ThreadPool-4]',
 'Sequential-Cache [Batch-250]', 
 'Sequential-Cache (Re-Post) [Batch-250]', 
 'Parallel-Cache [Batch-250]', 
 'Parallel-Cache (Re-Post) [Batch-250]',
 'Spring Batch [Batch Size 250]', 
 'Spring Batch [Batch Size 150]' 
]

duration = [
    1, 
    1,
    30, 
    13,
    30,
    10,
    30,
    0.2,
    22,
    0.2,
    1,
    1
]  # Sample JVM Memory values

cpu = [
    1,
    1,
    1,
    1,
    1,
    1,
    1,
    0.2,
    1,
    0.2,
    1,
    1,
]

# Set width of bars
bar_width = 0.3  # Adjust this value to increase or decrease spacing between groups

# Set position of bar on X axis
r1 = np.arange(len(implementation))
r2 = [x + bar_width for x in r1]

# Plotting
plt.figure(figsize=(15, 9))  # Larger figure size

# Plotting Duration
plt.bar(r1, duration, color='b', width=bar_width, edgecolor='grey', label='Duration (Seconds)')

# Plotting CPU 
plt.bar(r2, cpu, color='r', width=bar_width, edgecolor='grey', label='CPU')

# Adding values on top of bars
for i in range(len(implementation)):
    plt.text(r1[i] - 0.05, duration[i] + 0.001, str(duration[i]), color='black', fontweight='bold')
    plt.text(r2[i] - 0.05, cpu[i] + 0.001, str(cpu[i]), color='black', fontweight='bold')
   
# Adding labels and title
plt.xlabel('Implementation', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('SQL Server Metrics by Implementation')
plt.xticks([r + 1.5 * bar_width for r in range(len(implementation))], implementation)
plt.legend()
plt.yticks(np.arange(0, max(max(duration), max(cpu)) + 1, step=1))


# Displaying plot
plt.grid(True)
plt.xticks(rotation=100)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# SQL Server Writes
implementation = [
 'Sequential [Batch-250]', 
 'Sequential [Batch-150]', 
 'Parallel [Batch-250][ThreadPool-24]', 
 'Parallel [Batch-250][ThreadPool-4]', 
 'Parallel [Batch-150][ThreadPool-24]',
 'Parallel [Batch-150][ThreadPool-4]',
 'Sequential-Cache [Batch-250]', 
 'Sequential-Cache (Re-Post) [Batch-250]', 
 'Parallel-Cache [Batch-250]', 
 'Parallel-Cache (Re-Post) [Batch-250]',
 'Spring Batch [Batch Size 250]', 
 'Spring Batch [Batch Size 150]' 
]

logicalreads = [
    40581,
    26299,
    16342,
    15020,
    11422,
    26222,
    11422,
    2478,
    7804,
    2478,
    40419,
    25877
]

physicalreads = [
    1,
    30,
    1704,
    1728,
    1504,
    2,
    1504,
    0,
    1481,
    0,
    1,
    1
]

writes = [
    2121,
    1235,
    573,
    572,
    381,
    1224,
    381,
    0,
    333,
    0,
    2083,
    1244
]

# Set width of bars
bar_width = 0.3  # Adjust this value to increase or decrease spacing between groups

# Set position of bar on X axis
r1 = np.arange(len(implementation))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]


# Plotting
plt.figure(figsize=(15, 9))  # Larger figure size

# Plotting Logical Reads
plt.bar(r1, logicalreads, color='b', width=bar_width, edgecolor='grey', label='Logical Reads')

# Plotting Physical Reads 
plt.bar(r2, physicalreads, color='r', width=bar_width, edgecolor='grey', label='Physical Reads')

# Plotting Writes
plt.bar(r3, writes, color='orange', width=bar_width, edgecolor='grey', label='Writes')


# Adding values on top of bars
for i in range(len(implementation)):
    plt.text(r1[i] - 0.05, duration[i] + 0.001, str(duration[i]), color='black', fontweight='bold')
    plt.text(r2[i] - 0.05, cpu[i] + 0.001, str(cpu[i]), color='black', fontweight='bold')
    plt.text(r3[i] - 0.05, writes[i] + 1, str(writes[i]), color='black', fontweight='bold')
   
# Adding labels and title
plt.xlabel('Implementation', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('SQL Server Metrics by Implementation')
plt.xticks([r + 1.5 * bar_width for r in range(len(implementation))], implementation)
plt.legend()


# Displaying plot
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

implementation = [
    'Sequential-Cache', 
    'Sequential-Cache [Rate Limit]', 
]

elapsed_time = [
    12,
    4.18
]

# Define the positions of the bars
x_pos = np.arange(len(implementation))

plt.figure(figsize=(12, 8))
plt.bar(x_pos, elapsed_time, color='blue', width=0.2)  # Adjust width here
plt.xlabel('Implementation')
plt.ylabel('Elapsed Time')
plt.title('Elapsed Time vs Implementation')

# Set the positions and labels for the x-axis ticks
plt.xticks(x_pos, implementation, rotation=90)

for i in range(len(implementation)):
    plt.text(x_pos[i], elapsed_time[i], str(elapsed_time[i]), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#JVM Metrics

implementation = [
    'Sequential-Cache', 
    'Sequential-Cache [Rate Limit]', 
]



jvm_memory = [
    750,
    413,
]  # Sample JVM Memory values

jvm_cpu = [
    64.1,
    58.1
]


# Set width of bars
bar_width = 0.35

# Set position of bar on X axis
r1 = np.arange(len(implementation))
r2 = [x + bar_width for x in r1]

# Plotting
#plt.figure(figsize=(10, 6))
plt.figure(figsize=(12, 8))  # Larger figure size

# Plotting JVM Memory
plt.bar(r1, jvm_memory, color='b', width=bar_width, edgecolor='grey', label='JVM Memory -MB')

# Plotting JVM CPU
plt.bar(r2, jvm_cpu, color='r', width=bar_width, edgecolor='grey', label='JVM CPU %')

# Adding values on top of bars
for i in range(len(implementation)):
    plt.text(r1[i] - 0.05, jvm_memory[i] + 5, str(jvm_memory[i]), color='black', fontweight='bold')
    plt.text(r2[i] - 0.05, jvm_cpu[i] + 5, str(jvm_cpu[i]), color='black', fontweight='bold')

# Adding labels and title
plt.xlabel('Implementation', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('JVM Memory and CPU Usage by Implementation')
plt.xticks([r + bar_width / 2 for r in range(len(implementation))], implementation)
plt.legend()

# Displaying plot
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# SQL Server Metrics
implementation = [
    'Sequential-Cache', 
    'Sequential-Cache [Rate Limit]', 
]

duration = [
    7, 
    5.4,
]  

cpu = [
    1,
    0.84,
   
]

# Set width of bars
bar_width = 0.3  # Adjust this value to increase or decrease spacing between groups

# Set position of bar on X axis
r1 = np.arange(len(implementation))
r2 = [x + bar_width for x in r1]

# Plotting
plt.figure(figsize=(15, 9))  # Larger figure size

# Plotting Duration
plt.bar(r1, duration, color='b', width=bar_width, edgecolor='grey', label='Duration (Seconds)')

# Plotting CPU 
plt.bar(r2, cpu, color='r', width=bar_width, edgecolor='grey', label='CPU')

# Adding values on top of bars
for i in range(len(implementation)):
    plt.text(r1[i] - 0.05, duration[i] + 0.001, str(duration[i]), color='black', fontweight='bold')
    plt.text(r2[i] - 0.05, cpu[i] + 0.001, str(cpu[i]), color='black', fontweight='bold')
   
# Adding labels and title
plt.xlabel('Implementation', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('SQL Server Metrics by Implementation')
plt.xticks([r + 1.5 * bar_width for r in range(len(implementation))], implementation)
plt.legend()
plt.yticks(np.arange(0, max(max(duration), max(cpu)) + 1, step=1))


# Displaying plot
plt.grid(True)
plt.xticks(rotation=95)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
